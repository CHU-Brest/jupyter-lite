# %% [markdown]
# # Démo R
#
# Ce notebook tourne sur le kernel **xeus-r** compilé en WebAssembly, directement dans le navigateur.
#
# Sélectionnez le kernel **R (xeus)** si ce n'est pas déjà fait.

# %%
R.version.string

# %%
df <- data.frame(
  ville = c("Brest", "Brest", "Rennes", "Rennes"),
  annee = c(2023, 2024, 2023, 2024),
  valeur = c(10, 15, 7, 21)
)
aggregate(valeur ~ ville, data = df, FUN = sum)
